# %% [markdown]
# <a href="https://colab.research.google.com/github/mvvilori/DS-Coding-Dojo/blob/main/Average_Height_Olympics_Core.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %%
filename = '/content/athleteEventsNoPersonal(1).csv'
df = pd.read_csv(filename)

# %%
#Clean the dataset first

# %%
df.info
#There are 40616 Rows & 12 Columns
# Out:
# <bound method DataFrame.info of            ID   Age  Height         Team  NOC        Games  Year  Season  \
# 0           5  21.0   185.0  Netherlands  NED  1988 Winter  1988  Winter
# 1           5  21.0   185.0  Netherlands  NED  1988 Winter  1988  Winter
# 2           5  25.0   185.0  Netherlands  NED  1992 Winter  1992  Winter
# 3           5  25.0   185.0  Netherlands  NED  1992 Winter  1992  Winter
# 4           5  27.0   185.0  Netherlands  NED  1994 Winter  1994  Winter
# ...       ...   ...     ...          ...  ...          ...   ...     ...
# 40611  135567  28.0   183.0       Russia  RUS  2004 Summer  2004  Summer
# 40612  135570  27.0   176.0       Poland  POL  2014 Winter  2014  Winter
# 40613  135570  27.0   176.0       Poland  POL  2014 Winter  2014  Winter
# 40614  135571  30.0   185.0       Poland  POL  1998 Winter  1998  Winter
# 40615  135571  34.0   185.0       Poland  POL  2002 Winter  2002  Winter
#
#                  City          Sport  \
# ...

# %%
df.isna().sum()
#Age, Height & Medals have missing values. I think Height has missing values due to incorrect measurement type. Age is missing due to participants wanting to be part of the roster (younger contestants want to compette in a older devisions and vise versa). Medal is missing since only 3 medals are won per country per Event.
# Out:
# ID            0
# Age        1473
# Height     9001
# Team          0
# NOC           0
# Games         0
# Year          0
# Season        0
# City          0
# Sport         0
# Event         0
# Medal     34699
# dtype: int64

# %%
df['Age'].min()
#Minimum paticipant is 11 years old
# Out:
# 11.0

# %%
#clean data
df.duplicated().sum()
# Out:
# 207

# %%
df[df.duplicated(keep = False)]
# Out:
#            ID   Age  Height           Team  NOC        Games  Year  Season  \
# 1657     6016  72.0     NaN  Great Britain  GBR  1948 Summer  1948  Summer
# 1658     6016  72.0     NaN  Great Britain  GBR  1948 Summer  1948  Summer
# 1820     6437  50.0     NaN        Germany  GER  1936 Summer  1936  Summer
# 1821     6437  50.0     NaN        Germany  GER  1936 Summer  1936  Summer
# 1977     7082  47.0     NaN    Netherlands  NED  1936 Summer  1936  Summer
# ...       ...   ...     ...            ...  ...          ...   ...     ...
# 40114  134046  41.0     NaN         Mexico  MEX  1928 Summer  1928  Summer
# 40115  134046  41.0     NaN         Mexico  MEX  1928 Summer  1928  Summer
# 40116  134046  41.0     NaN         Mexico  MEX  1928 Summer  1928  Summer
# 40117  134046  41.0     NaN         Mexico  MEX  1928 Summer  1928  Summer
# 40118  134046  41.0     NaN         Mexico  MEX  1928 Summer  1928  Summer
#
#             City             Sport  \
# ...

# %%
df.drop_duplicates(inplace = True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# ID          int64
# Age       float64
# Height    float64
# Team       object
# NOC        object
# Games      object
# Year        int64
# Season     object
# City       object
# Sport      object
# Event      object
# Medal      object
# dtype: object

# %%
df['Team'].value_counts()
# Out:
# United States                   2500
# Great Britain                   1751
# France                          1742
# Italy                           1607
# Germany                         1452
#                                 ...
# Sif                                1
# Ormsund Roklub-2                   1
# Three Leaves                       1
# La Salle Turnverein, Chicago       1
# Digby                              1
# Name: Team, Length: 646, dtype: int64

# %%
print(df['Team'].unique())
#This dataset shows a total of 600+ unique entries (due to questions, I opted out to skipping to clean this column)
# Out:
# ['Netherlands' 'United States' 'Finland' 'Norway' 'Taifun' 'Estonia'
#  'Spain' 'Iran' 'Bulgaria' 'Russia' 'Mexico' 'Soviet Union' 'Chile'
#  'Hungary' 'Iraq' 'Lebanon' 'Pakistan' 'Azerbaijan' 'Thessalonki-1'
#  'Ireland' 'South Africa' 'Egypt' 'Sudan' 'United Arab Republic' 'Algeria'
#  'Qatar' 'Malaysia' 'Singapore' 'Uzbekistan' 'Japan' 'Brazil' 'Germany'
#  'West Germany' 'Sweden' "Cote d'Ivoire" 'France' 'Ukraine' 'Libya'
#  'Costa Rica' 'Great Britain' 'Georgia' 'Guyana' 'Bangladesh' 'Jordan'
#  'Palestine' 'Kazakhstan' 'Italy' 'Uruguay' 'Venezuela' 'Belgium'
#  'Morocco' 'Ghana' 'Honduras' 'Argentina' 'El Salvador' 'Canada' 'Turkey'
#  'Seychelles' 'East Germany' 'Mauritania' 'Greece' 'Poland'
#  'New York Athletic Club #2-4' 'Trinidad and Tobago' 'Australia'
#  'Switzerland' 'Nigeria' 'Kenya' 'Nigeria-2' 'Armenia' 'Ethiopia'
#  'Lithuania' 'Puerto Rico' 'Mongolia' 'Switzerland-2' 'Austria'
#  'Afghanistan' 'Rwanda' 'Panama' 'Benin' 'Haiti' 'Romania' 'Luxembourg'
# ...

# %%
df['NOC'].value_counts()
# Out:
# USA    2638
# GBR    1894
# FRA    1860
# ITA    1675
# GER    1535
#        ...
# TUV       1
# COM       1
# MHL       1
# PLW       1
# VNM       1
# Name: NOC, Length: 222, dtype: int64

# %%
df.isna().sum()
# Out:
# ID            0
# Age        1446
# Height     8796
# Team          0
# NOC           0
# Games         0
# Year          0
# Season        0
# City          0
# Sport         0
# Event         0
# Medal     34493
# dtype: int64

# %%
df['Age'].interpolate(method="values", inplace=True)

# %%
df['Height'].interpolate(method="values", inplace=True)

# %%
df['Medal'].fillna('No Medal', inplace=True)

# %%
df
# Out:
#            ID   Age  Height         Team  NOC        Games  Year  Season  \
# 0           5  21.0   185.0  Netherlands  NED  1988 Winter  1988  Winter
# 1           5  21.0   185.0  Netherlands  NED  1988 Winter  1988  Winter
# 2           5  25.0   185.0  Netherlands  NED  1992 Winter  1992  Winter
# 3           5  25.0   185.0  Netherlands  NED  1992 Winter  1992  Winter
# 4           5  27.0   185.0  Netherlands  NED  1994 Winter  1994  Winter
# ...       ...   ...     ...          ...  ...          ...   ...     ...
# 40611  135567  28.0   183.0       Russia  RUS  2004 Summer  2004  Summer
# 40612  135570  27.0   176.0       Poland  POL  2014 Winter  2014  Winter
# 40613  135570  27.0   176.0       Poland  POL  2014 Winter  2014  Winter
# 40614  135571  30.0   185.0       Poland  POL  1998 Winter  1998  Winter
# 40615  135571  34.0   185.0       Poland  POL  2002 Winter  2002  Winter
#
#                  City          Sport  \
# 0             Calgary  Speed Skating
# ...

# %%
df['Age'].value_counts()
# Out:
# 23.000    3335
# 24.000    3216
# 22.000    3156
# 25.000    2973
# 21.000    2876
#           ...
# 19.600       1
# 20.800       1
# 36.625       1
# 42.500       1
# 30.200       1
# Name: Age, Length: 344, dtype: int64

# %%
df['Height'].value_counts()
# Out:
# 180.000000    2077
# 170.000000    1832
# 178.000000    1689
# 175.000000    1625
# 168.000000    1363
#               ...
# 195.400000       1
# 173.100000       1
# 173.833333       1
# 169.545455       1
# 173.700000       1
# Name: Height, Length: 1544, dtype: int64

# %%
df.describe()
# Out:
#                   ID           Age        Height          Year
# count   40409.000000  40409.000000  40409.000000  40409.000000
# mean    68154.281348     25.521132    175.650307   1978.907174
# std     38836.054638      6.224269     10.077303     29.706622
# min         5.000000     11.000000    135.000000   1896.000000
# 25%     34631.000000     21.000000    169.000000   1960.000000
# 50%     68074.000000     24.500000    176.000000   1988.000000
# 75%    101475.000000     28.000000    182.000000   2004.000000
# max    135571.000000     74.000000    221.000000   2016.000000

# %%
df.shape
#40409 rows & 12 columns
# Out:
# (40409, 12)

# %%
df['City'].value_counts()
#There are 3347 entries for London
# Out:
# London                    3347
# Athina                    2325
# Beijing                   2056
# Sydney                    2049
# Atlanta                   2037
# Rio de Janeiro            2037
# Barcelona                 1973
# Seoul                     1852
# Los Angeles               1805
# Munich                    1525
# Helsinki                  1305
# Roma                      1259
# Montreal                  1253
# Mexico City               1146
# Moskva                    1116
# Tokyo                     1087
# Paris                     1022
# Berlin                     890
# Sochi                      787
# Amsterdam                  691
# Torino                     687
# Vancouver                  673
# Melbourne                  670
# Antwerpen                  645
# Salt Lake City             639
# Stockholm                  600
# Nagano                     586
# Albertville                545
# Lillehammer                541
# Innsbruck                  504
# ...

# %%
#How many athletes who participated in the Sport "Tug-Of-War" were from Team "Sweden" in our sample dataset? #inpsire by https://stackoverflow.com/questions/22086116/how-do-you-filter-pandas-dataframes-by-multiple-columns
#Number of athletes who participated in the Tugofwar is 6
tugofwar = df[(df['Team']=='Sweden') & (df['Sport']=='Tug-Of-War')]
tugofwar
# Out:
#           ID   Age      Height    Team  NOC        Games  Year  Season  \
# 10023  34205  22.0  174.666667  Sweden  SWE  1908 Summer  1908  Summer
# 12681  43105  23.0  177.500000  Sweden  SWE  1906 Summer  1906  Summer
# 13015  44087  29.0  182.000000  Sweden  SWE  1906 Summer  1906  Summer
# 16250  55169  23.0  180.000000  Sweden  SWE  1908 Summer  1908  Summer
# 19048  64266  21.0  171.000000  Sweden  SWE  1908 Summer  1908  Summer
# 20550  68647  26.0  190.000000  Sweden  SWE  1906 Summer  1906  Summer
#
#          City       Sport                        Event     Medal
# 10023  London  Tug-Of-War  Tug-Of-War Men's Tug-Of-War  No Medal
# 12681  Athina  Tug-Of-War  Tug-Of-War Men's Tug-Of-War    Bronze
# 13015  Athina  Tug-Of-War  Tug-Of-War Men's Tug-Of-War    Bronze
# 16250  London  Tug-Of-War  Tug-Of-War Men's Tug-Of-War  No Medal
# 19048  London  Tug-Of-War  Tug-Of-War Men's Tug-Of-War  No Medal
# 20550  Athina  Tug-Of-War  Tug-Of-War Men's Tug-Of-War    Bronze

# %%
#How many Gold medals were awarded to athletes who were over 40 years old?
#10 40 yr olds
fw = df[(df['Medal']=='Gold') & (df['Age']==40)]
fw
# Out:
#            ID   Age      Height                               Team  NOC  \
# 8475    29040  40.0  175.000000                      Great Britain  GBR
# 10903   37028  40.0  185.153846                            Germany  GER
# 10904   37028  40.0  186.615385                            Germany  GER
# 12320   41826  40.0  175.666667                      Great Britain  GBR
# 12321   41826  40.0  177.500000                    Great Britain-1  GBR
# 14093   47761  40.0  181.200000  Osborne Swimming Club, Manchester  GBR
# 14515   49111  40.0  175.000000                            Germany  GER
# 19572   65878  40.0  177.000000                             France  FRA
# 23947   79892  40.0  171.500000                       Roehampton-1  GBR
# 30488  101605  40.0  176.500000                             Merope  ITA
#
#              Games  Year  Season            City             Sport  \
# 8475   1908 Summer  1908  Summer          London           Archery
# ...

# %%
#Avg Height All rows included
AvgH = df['Height'].mean()
AvgH
# Out:
# 175.65030742409266

# %%
#All rows included, but grouped by Event.
df.groupby(['Event'])[['Height']].mean()
# Out:
#                                                     Height
# Event
# Alpine Skiing Men's Combined                    176.791228
# Alpine Skiing Men's Downhill                    177.277668
# Alpine Skiing Men's Giant Slalom                176.206583
# Alpine Skiing Men's Slalom                      176.021889
# Alpine Skiing Men's Super G                     178.866340
# ...                                                    ...
# Wrestling Women's Flyweight, Freestyle          158.100000
# Wrestling Women's Heavyweight, Freestyle        173.444444
# Wrestling Women's Light-Heavyweight, Freestyle  170.000000
# Wrestling Women's Lightweight, Freestyle        162.666667
# Wrestling Women's Middleweight, Freestyle       164.533333
#
# [726 rows x 1 columns]
